# %%
import sys

sys.path.append("..")
from aktipp.scraping import scrape_many_seasons_openligadb
from aktipp.normalize import normalize_many_seasons_openligadb
from aktipp.etl import (
    clean_openligadb,
    create_performance_openligadb,
    create_standings_openligadb,
    FeatureBuilderOpenligadb,
)

# %% [markdown]
# ## Parameters

# %%
leagues = ["bl1", "bl2", "bl3"]
seasons = range(2000, 2025)
data_path = "/home/fabian/Project-Data/AK-Tippspiel/openligadb/"

# %% [markdown]
# ## Dowload, normnalize and clean openligadb data

# %%
scrape_many_seasons_openligadb(leagues, seasons, data_path)
normalize_many_seasons_openligadb(leagues, seasons, data_path)
clean_openligadb(data_path)
# Out:
# bl1 2000 is not available and will be skipped.
# bl1 2001 has been loaded.
# bl1 2002 has been loaded.
# bl1 2003 has been loaded.
# bl1 2004 has been loaded.
# bl1 2005 has been loaded.
# bl1 2006 has been loaded.
# bl1 2007 has been loaded.
# bl1 2008 has been loaded.
# bl1 2009 has been loaded.
# bl1 2010 has been loaded.
# bl1 2011 has been loaded.
# bl1 2012 has been loaded.
# bl1 2013 has been loaded.
# bl1 2014 has been loaded.
# bl1 2015 has been loaded.
# bl1 2016 has been loaded.
# bl1 2017 has been loaded.
# bl1 2018 has been loaded.
# bl1 2019 has been loaded.
# bl1 2020 has been loaded.
# bl1 2021 has been loaded.
# bl1 2022 has been loaded.
# bl1 2023 has been loaded.
# bl1 2024 has been loaded.
# bl2 2000 is not available and will be skipped.
# bl2 2001 is not available and will be skipped.
# bl2 2002 is not available and will be skipped.
# bl2 2003 is not available and will be skipped.
# bl2 2004 is not available and will be skipped.
# bl2 2005 is not available and will be skipped.
# bl2 2006 has been loaded.
# bl2 2007 has been loaded.
# bl2 2008 has been loaded.
# bl2 2009 has been loaded.
# bl2 2010 has been loaded.
# bl2 2011 has been loaded.
# bl2 2012 has been loaded.
# bl2 2013 has been loaded.
# bl2 2014 has been loaded.
# bl2 2015 has been loaded.
# bl2 2016 has been loaded.
# bl2 2017 has been loaded.
# bl2 2018 has been loaded.
# bl2 2019 has been loaded.
# bl2 2020 has been loaded.
# bl2 2021 has been loaded.
# bl2 2022 has been loaded.
# bl2 2023 has been loaded.
# bl2 2024 has been loaded.
# bl3 2000 is not available and will be skipped.
# bl3 2001 is not available and will be skipped.
# bl3 2002 is not available and will be skipped.
# bl3 2003 is not available and will be skipped.
# bl3 2004 is not available and will be skipped.
# bl3 2005 is not available and will be skipped.
# bl3 2006 is not available and will be skipped.
# bl3 2007 is not available and will be skipped.
# bl3 2008 has been loaded.
# bl3 2009 has been loaded.
# bl3 2010 has been loaded.
# bl3 2011 has been loaded.
# bl3 2012 has been loaded.
# bl3 2013 has been loaded.
# bl3 2014 has been loaded.
# bl3 2015 has been loaded.
# bl3 2016 has been loaded.
# bl3 2017 has been loaded.
# bl3 2018 has been loaded.
# bl3 2019 has been loaded.
# bl3 2020 has been loaded.
# bl3 2021 has been loaded.
# bl3 2022 has been loaded.
# bl3 2023 has been loaded.
# bl3 2024 has been loaded.
# bl1 2000 is not available and will be skipped.
# bl1 2001 has no matchResults. Only meta data.
# bl1 2001 has been normalized.
# bl1 2002 has been normalized.
# bl1 2003 has been normalized.
# bl1 2004 has been normalized.
# bl1 2005 has been normalized.
# bl1 2006 has been normalized.
# bl1 2007 has been normalized.
# bl1 2008 has been normalized.
# bl1 2009 has been normalized.
# bl1 2010 has been normalized.
# bl1 2011 has been normalized.
# bl1 2012 has been normalized.
# bl1 2013 has been normalized.
# bl1 2014 has been normalized.
# bl1 2015 has been normalized.
# bl1 2016 has been normalized.
# bl1 2017 has been normalized.
# bl1 2018 has been normalized.
# bl1 2019 has been normalized.
# bl1 2020 has been normalized.
# bl1 2021 has been normalized.
# bl1 2022 has been normalized.
# bl1 2023 has been normalized.
# bl1 2024 has been normalized.
# bl2 2000 is not available and will be skipped.
# bl2 2001 is not available and will be skipped.
# bl2 2002 is not available and will be skipped.
# bl2 2003 is not available and will be skipped.
# bl2 2004 is not available and will be skipped.
# bl2 2005 is not available and will be skipped.
# bl2 2006 has been normalized.
# bl2 2007 has been normalized.
# bl2 2008 has been normalized.
# bl2 2009 has been normalized.
# bl2 2010 has been normalized.
# bl2 2011 has been normalized.
# bl2 2012 has been normalized.
# bl2 2013 has been normalized.
# bl2 2014 has been normalized.
# bl2 2015 has been normalized.
# bl2 2016 has been normalized.
# bl2 2017 has been normalized.
# bl2 2018 has been normalized.
# bl2 2019 has been normalized.
# bl2 2020 has been normalized.
# bl2 2021 has been normalized.
# bl2 2022 has been normalized.
# bl2 2023 has been normalized.
# bl2 2024 has been normalized.
# bl3 2000 is not available and will be skipped.
# bl3 2001 is not available and will be skipped.
# bl3 2002 is not available and will be skipped.
# bl3 2003 is not available and will be skipped.
# bl3 2004 is not available and will be skipped.
# bl3 2005 is not available and will be skipped.
# bl3 2006 is not available and will be skipped.
# bl3 2007 is not available and will be skipped.
# bl3 2008 has been normalized.
# bl3 2009 has been normalized.
# bl3 2010 has been normalized.
# bl3 2011 has been normalized.
# bl3 2012 has been normalized.
# bl3 2013 has been normalized.
# bl3 2014 has been normalized.
# bl3 2015 has been normalized.
# bl3 2016 has been normalized.
# bl3 2017 has been normalized.
# bl3 2018 has been normalized.
# bl3 2019 has been normalized.
# bl3 2020 has been normalized.
# bl3 2021 has been normalized.
# bl3 2022 has been normalized.
# bl3 2023 has been normalized.
# bl3 2024 has been normalized.

# %% [markdown]
# ## Create feature data

# %%
create_performance_openligadb(
    match_results_data_path=data_path + "matchResults_clean.parquet",
    performance_data_path=data_path + "overall_performance.parquet",
    performance_class="overall",
)

# %%
create_performance_openligadb(
    match_results_data_path=data_path + "matchResults_clean.parquet",
    performance_data_path=data_path + "home_away_performance.parquet",
    performance_class="home_away",
)

# %%
create_standings_openligadb(
    match_results_data_path=data_path + "matchResults_clean.parquet",
    standings_data_path=data_path + "overall_standings.parquet",
    standings_class="overall",
)

# %%
create_standings_openligadb(
    match_results_data_path=data_path + "matchResults_clean.parquet",
    standings_data_path=data_path + "home_standings.parquet",
    standings_class="home",
)

# %%
create_standings_openligadb(
    match_results_data_path=data_path + "matchResults_clean.parquet",
    standings_data_path=data_path + "away_standings.parquet",
    standings_class="away",
)

# %% [markdown]
# ## Data for class_result

# %%
builder = FeatureBuilderOpenligadb()
df = builder.get_features(
    match_results_data_path="/home/fabian/Project-Data/AK-Tippspiel/openligadb/matchResults_clean.parquet",
    features={
        "overall_standings": "/home/fabian/Project-Data/AK-Tippspiel/openligadb/overall_standings.parquet",
        "overall_performance": "/home/fabian/Project-Data/AK-Tippspiel/openligadb/overall_performance.parquet",
    },
    target="result_class",
).sink_parquet(data_path + "openligadb_result_class_dataset.parquet")

# %%
builder = FeatureBuilderOpenligadb()
df = builder.get_features(
    match_results_data_path="/home/fabian/Project-Data/AK-Tippspiel/openligadb/matchResults_clean.parquet",
    features={
        "overall_standings": "/home/fabian/Project-Data/AK-Tippspiel/openligadb/overall_standings.parquet",
        "overall_performance": "/home/fabian/Project-Data/AK-Tippspiel/openligadb/overall_performance.parquet",
    },
    target="result_class",
    mode="predict",
).sink_parquet(data_path + "openligadb_result_class_predict.parquet")
